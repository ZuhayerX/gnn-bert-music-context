# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
PROJECT_PATH = "/content/drive/MyDrive/gnn_bert_music_project"

FMA_PATH = PROJECT_PATH + "/datasets/fma"

MUSICCAPS_PATH = PROJECT_PATH + "/datasets/musiccaps"

PROCESSED_PATH = PROJECT_PATH + "/processed"

print(FMA_PATH)
# Out:
# /content/drive/MyDrive/gnn_bert_music_project/datasets/fma

# %%
import os

for root, dirs, files in os.walk(FMA_PATH):
    level = root.replace(FMA_PATH,'').count(os.sep)

    if level < 2:
        print(root)
        for f in files[:5]:
            print("   ",f)
# Out:
# /content/drive/MyDrive/gnn_bert_music_project/datasets/fma
#     fma_metadata.zip
#     fma_medium.zip
# /content/drive/MyDrive/gnn_bert_music_project/datasets/fma/fma_medium
# /content/drive/MyDrive/gnn_bert_music_project/datasets/fma/fma_metadata

# %%
import zipfile
import os

metadata_zip = FMA_PATH + "/fma_metadata.zip"

extract_path = FMA_PATH + "/fma_metadata"

with zipfile.ZipFile(metadata_zip,'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Metadata extracted")
# Out:
# Metadata extracted

# %%
import pandas as pd

# %%
tracks_file = (
    FMA_PATH +
    "/fma_metadata/fma_metadata/tracks.csv"
)

tracks = pd.read_csv(
    tracks_file,
    header=[0,1],
    index_col=0
)

tracks.head()
# Out:
#             album                                                     \
#          comments         date_created        date_released engineer
# track_id
# 2               0  2008-11-26 01:44:45  2009-01-05 00:00:00      NaN
# 3               0  2008-11-26 01:44:45  2009-01-05 00:00:00      NaN
# 5               0  2008-11-26 01:44:45  2009-01-05 00:00:00      NaN
# 10              0  2008-11-26 01:45:08  2008-02-06 00:00:00      NaN
# 20              0  2008-11-26 01:45:05  2009-01-06 00:00:00      NaN
#
#                                                                           \
#          favorites id                                information listens
# track_id
# 2                4  1                                    <p></p>    6073
# 3                4  1                                    <p></p>    6073
# 5                4  1                                    <p></p>    6073
# 10               4  6                                        NaN   47632
# ...

# %%
tracks.shape
# Out:
# (106574, 52)

# %%
audio_zip = FMA_PATH + "/fma_medium.zip"

audio_extract = FMA_PATH + "/fma_medium"

with zipfile.ZipFile(audio_zip,'r') as zip_ref:
    zip_ref.extractall(audio_extract)

print("Audio extracted")
# Out:
# Audio extracted

# %%
# !pip install librosa soundfile

# %%
import librosa

audio_path = (
    FMA_PATH+
    "/fma_medium/fma_medium/000/000002.mp3"
)

audio, sr = librosa.load(
    audio_path,
    sr=22050
)

print(audio.shape)
print(sr)
# Out:
# (660984,)
# 22050

# %%
import os

PROJECT_PATH = "/content/drive/MyDrive/gnn_bert_music_project"

for item in os.listdir(PROJECT_PATH):
    print(item)
# Out:
# datasets
# musiccaps
# processed
# models
# results

# %%
DATASET_PATH = PROJECT_PATH + "/datasets"

for item in os.listdir(DATASET_PATH):
    print(item)
# Out:
# fma
# musiccaps

# %%
import pandas as pd
import os

os.listdir(MUSICCAPS_PATH)
# Out:
# ['musiccaps.csv']

# %%
import pandas as pd

musiccaps_file = MUSICCAPS_PATH + "/musiccaps.csv"

musiccaps = pd.read_csv(musiccaps_file)

print(musiccaps.shape)
musiccaps.head()
# Out:
# (5521, 9)
#           ytid  start_s  end_s  \
# 0  -0Gj8-vB1q4       30     40
# 1  -0SdAVK79lg       30     40
# 2  -0vPFx-wRRI       30     40
# 3  -0xzrMun0Rs       30     40
# 4  -1LrH01Ei1w       30     40
#
#                             audioset_positive_labels  \
# 0                       /m/0140xf,/m/02cjck,/m/04rlf
# 1  /m/0155w,/m/01lyv,/m/0342h,/m/042v_gx,/m/04rlf...
# 2                                /m/025_jnm,/m/04rlf
# 3                                 /m/01g90h,/m/04rlf
# 4                                /m/02p0sh1,/m/04rlf
#
#                                          aspect_list  \
# 0  ['low quality', 'sustained strings melody', 's...
# 1  ['guitar song', 'piano backing', 'simple percu...
# 2  ['amateur recording', 'finger snipping', 'male...
# 3  ['backing track', 'jazzy', 'digital drums', 'p...
# 4  ['rubab instrument', 'repetitive melody on dif...
#
#                                              caption  author_id  \
# ...

# %%
musiccaps.columns
# Out:
# Index(['ytid', 'start_s', 'end_s', 'audioset_positive_labels', 'aspect_list',
#        'caption', 'author_id', 'is_balanced_subset', 'is_audioset_eval'],
#       dtype='object')

# %%
musiccaps[['caption']].head(10)
# Out:
#                                              caption
# 0  The low quality recording features a ballad so...
# 1  This song features an electric guitar as the m...
# 2  a male voice is singing a melody with changing...
# 3  This song contains digital drums playing a sim...
# 4  This song features a rubber instrument being p...
# 5  This clip is three tracks playing consecutivel...
# 6  A male singer sings this groovy melody. The so...
# 7  someone is playing a high pitched melody on a ...
# 8  The Pop song features a soft female vocal sing...
# 9  low fidelity audio from a live performance fea...

# %%
musiccaps.isnull().sum()
# Out:
# ytid                        0
# start_s                     0
# end_s                       0
# audioset_positive_labels    0
# aspect_list                 0
# caption                     0
# author_id                   0
# is_balanced_subset          0
# is_audioset_eval            0
# dtype: int64

# %%
musiccaps_clean = musiccaps.dropna()

musiccaps_clean.to_csv(
    PROJECT_PATH + "/processed/musiccaps_clean.csv",
    index=False
)

print("Saved:", musiccaps_clean.shape)
# Out:
# Saved: (5521, 9)

# %%
musiccaps.shape
musiccaps.columns
musiccaps.head()
# Out:
#           ytid  start_s  end_s  \
# 0  -0Gj8-vB1q4       30     40
# 1  -0SdAVK79lg       30     40
# 2  -0vPFx-wRRI       30     40
# 3  -0xzrMun0Rs       30     40
# 4  -1LrH01Ei1w       30     40
#
#                             audioset_positive_labels  \
# 0                       /m/0140xf,/m/02cjck,/m/04rlf
# 1  /m/0155w,/m/01lyv,/m/0342h,/m/042v_gx,/m/04rlf...
# 2                                /m/025_jnm,/m/04rlf
# 3                                 /m/01g90h,/m/04rlf
# 4                                /m/02p0sh1,/m/04rlf
#
#                                          aspect_list  \
# 0  ['low quality', 'sustained strings melody', 's...
# 1  ['guitar song', 'piano backing', 'simple percu...
# 2  ['amateur recording', 'finger snipping', 'male...
# 3  ['backing track', 'jazzy', 'digital drums', 'p...
# 4  ['rubab instrument', 'repetitive melody on dif...
#
#                                              caption  author_id  \
# ...

# %%
musiccaps.shape
# Out:
# (5521, 9)

# %%
musiccaps.isnull().sum()
# Out:
# ytid                        0
# start_s                     0
# end_s                       0
# audioset_positive_labels    0
# aspect_list                 0
# caption                     0
# author_id                   0
# is_balanced_subset          0
# is_audioset_eval            0
# dtype: int64

# %%
musiccaps["caption_length"] = (
    musiccaps["caption"]
    .apply(lambda x: len(str(x).split()))
)

musiccaps["caption_length"].describe()
# Out:
# count    5521.000000
# mean       48.968303
# std        17.329780
# min         3.000000
# 25%        37.000000
# 50%        46.000000
# 75%        60.000000
# max       136.000000
# Name: caption_length, dtype: float64

# %%
for i in range(5):
    print("\nCaption", i+1)
    print(musiccaps.iloc[i]["caption"])
# Out:
# Caption 1
# The low quality recording features a ballad song that contains sustained strings, mellow piano melody and soft female vocal singing over it. It sounds sad and soulful, like something you would hear at Sunday services.
#
# Caption 2
# This song features an electric guitar as the main instrument. The guitar plays a descending run in the beginning then plays an arpeggiated chord followed by a double stop hammer on to a higher note and a descending slide followed by a descending chord run. The percussion plays a simple beat using rim shots. The percussion plays in common time. The bass plays only one note on the first count of each bar. The piano plays backing chords. There are no voices in this song. The mood of this song is relaxing. This song can be played in a coffee shop.
#
# Caption 3
# ...

# %%
import os

os.listdir(FMA_PATH)
# Out:
# ['fma_metadata.zip', 'fma_medium.zip', 'fma_medium', 'fma_metadata']

# %%
for root, dirs, files in os.walk(FMA_PATH):
    print(root)
    print(files[:5])
    break
# Out:
# /content/drive/MyDrive/gnn_bert_music_project/datasets/fma
# ['fma_metadata.zip', 'fma_medium.zip']

# %%
import os

print(os.listdir(FMA_PATH))
# Out:
# ['fma_metadata.zip', 'fma_medium.zip', 'fma_medium', 'fma_metadata']

# %%
for root, dirs, files in os.walk(FMA_PATH + "/fma_metadata"):
    print(root)
    print(files[:10])
    break
# Out:
# /content/drive/MyDrive/gnn_bert_music_project/datasets/fma/fma_metadata
# []

# %%
import pandas as pd

tracks_path = (
    FMA_PATH +
    "/fma_metadata/fma_metadata/tracks.csv"
)

tracks = pd.read_csv(
    tracks_path,
    header=[0,1],
    index_col=0
)

tracks.head()
# Out:
#             album                                                     \
#          comments         date_created        date_released engineer
# track_id
# 2               0  2008-11-26 01:44:45  2009-01-05 00:00:00      NaN
# 3               0  2008-11-26 01:44:45  2009-01-05 00:00:00      NaN
# 5               0  2008-11-26 01:44:45  2009-01-05 00:00:00      NaN
# 10              0  2008-11-26 01:45:08  2008-02-06 00:00:00      NaN
# 20              0  2008-11-26 01:45:05  2009-01-06 00:00:00      NaN
#
#                                                                           \
#          favorites id                                information listens
# track_id
# 2                4  1                                    <p></p>    6073
# 3                4  1                                    <p></p>    6073
# 5                4  1                                    <p></p>    6073
# 10               4  6                                        NaN   47632
# ...

# %%
tracks.shape
# Out:
# (106574, 52)

# %%
medium_tracks = tracks[
    tracks[('set','subset')] == 'medium'
]

medium_tracks.shape
# Out:
# (17000, 52)

# %%
medium_tracks[('track','genre_top')].value_counts()
# Out:
# (track, genre_top)
# Rock                   6103
# Electronic             5314
# Experimental           1251
# Hip-Hop                1201
# Classical               619
# Folk                    519
# Old-Time / Historic     510
# Jazz                    384
# Instrumental            350
# Pop                     186
# Country                 178
# Soul-RnB                154
# Spoken                  118
# Blues                    74
# Easy Listening           21
# International            18
# Name: count, dtype: int64

# %%
os.listdir(FMA_PATH)
# Out:
# ['fma_metadata.zip', 'fma_medium.zip', 'fma_medium', 'fma_metadata']

# %%
genre_counts = medium_tracks[
    ('track','genre_top')
].value_counts()

genre_counts
# Out:
# (track, genre_top)
# Rock                   6103
# Electronic             5314
# Experimental           1251
# Hip-Hop                1201
# Classical               619
# Folk                    519
# Old-Time / Historic     510
# Jazz                    384
# Instrumental            350
# Pop                     186
# Country                 178
# Soul-RnB                154
# Spoken                  118
# Blues                    74
# Easy Listening           21
# International            18
# Name: count, dtype: int64

# %%
fma_audio_path = FMA_PATH + "/fma_medium/fma_medium"

for root, dirs, files in os.walk(fma_audio_path):
    if len(files)>0:
        print(root)
        print(files[:5])
        break
# Out:
# /content/drive/MyDrive/gnn_bert_music_project/datasets/fma/fma_medium/fma_medium
# ['README.txt', 'checksums']

# %%
# !pip install librosa soundfile -q

# %%
import librosa

sample_file = (
    fma_audio_path +
    "/000/000002.mp3"
)

audio, sr = librosa.load(
    sample_file,
    sr=22050
)

print("Sample rate:", sr)
print("Audio length:", len(audio))
# Out:
# Sample rate: 22050
# Audio length: 660984
